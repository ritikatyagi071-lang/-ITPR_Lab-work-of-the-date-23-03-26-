# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikatyagi071-lang/-ITPR_Lab-work-of-the-date-23-03-26-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python program for common elements in three lists
l1 = [1, 2, 3]
l2 = [2, 3, 4]
l3 = [2, 5, 3]

result = list(set(l1) & set(l2) & set(l3))

print(result)
